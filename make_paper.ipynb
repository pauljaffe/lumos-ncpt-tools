# %%
from manuscript.table1 import Table1
from manuscript.table2 import Table2

# %%
#data_directory = 'CHANGE/TO/DATA/DIRECTORY' 
data_directory = '/mnt/efs/home/paul/ncpt_data_descriptor/split_by_battery' # CHANGE
#save_directory = 'CHANGE/TO/SAVE/DIRECTORY' 
save_directory = '/mnt/efs/home/paul/ncpt_data_descriptor/manuscript_figs' # CHANGE
t1_figsize = figsize = (12, 15)
t2_figsize = figsize = (15, 4)

t1 = Table1(data_directory, save_directory, t1_figsize)
t1.make_table()

t2 = Table2(data_directory, save_directory, t2_figsize)
t2.make_table()
